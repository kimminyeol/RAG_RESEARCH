# %%
# import utils

import os
import openai
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader(
    input_files=["/Users/mac/AIworkspace/LLMWORKSPACE/Advanced_RAG/data/Understanding_Climate_Change.pdf"]
).load_data()

# %%
print(type(documents), "\n")
print(len(documents), "\n")
print(type(documents[0]))
print(documents[0])
# Out:
# <class 'list'>
#
# 33
#
# <class 'llama_index.core.schema.Document'>
# Doc ID: fede1905-e2f6-4d2a-a9f5-cc71471c73ae
# Text: Understanding Climate Change  Chapter 1: Introduction to Climate
# Change  Climate change refers to significant, long-term changes in the
# global climate. The term  "global climate" encompasses the planet's
# overall weather patterns, including temperature,  precipitation, and
# wind patterns, over an extended period. Over the past century, human
# acti...

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)

# %%
from utils import build_sentence_window_index

sentence_index = build_sentence_window_index(
    document,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="sentence_index"
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from utils import build_sentence_window_index
#       3 sentence_index = build_sentence_window_index(
#       4     document,
#       5     llm,
#       6     embed_model="local:BAAI/bge-small-en-v1.5",
#       7     save_dir="sentence_index"
#       8 )
#
# File ~/AIworkspace/LLMWORKSPACE/Advanced_RAG/RAG_deepai/utils.py:47
#      43     tru_recorder = TruLlama(query_engine, app_id=app_id, feedbacks=feedbacks)
#      44     return tru_recorder
# ---> 47 from llama_index.core.service_context import ServiceContext, VectorStoreIndex, StorageContext
#      48 from llama_index.node_parser import SentenceWindowNodeParser
#      49 from llama_index.indices.postprocessor import MetadataReplacementPostProcessor
#
# ImportError: cannot import name 'VectorStoreIndex' from 'llama_index.core.service_context' (/opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages/llama_index/core/service_context.py)

# %%
! pip install trulens_eval
# Out:
# Collecting trulens_eval
#   Downloading trulens_eval-1.2.7-py3-none-any.whl.metadata (1.1 kB)
# Collecting trulens-core<2.0.0,>=1.0.0 (from trulens_eval)
#   Downloading trulens_core-1.2.7-py3-none-any.whl.metadata (1.5 kB)
# Collecting trulens-dashboard<2.0.0,>=1.0.0 (from trulens_eval)
#   Downloading trulens_dashboard-1.2.7-py3-none-any.whl.metadata (1.6 kB)
# Collecting trulens-feedback<2.0.0,>=1.0.0 (from trulens_eval)
#   Downloading trulens_feedback-1.2.7-py3-none-any.whl.metadata (17 kB)
# Collecting alembic<2.0.0,>=1.8.1 (from trulens-core<2.0.0,>=1.0.0->trulens_eval)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: dill>=0.3.8 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (0.3.8)
# Requirement already satisfied: importlib-resources<7.0,>=6.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (6.4.5)
# Collecting munch<3.0,>=2.5 (from trulens-core<2.0.0,>=1.0.0->trulens_eval)
#   Downloading munch-2.5.0-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nest-asyncio<2.0,>=1.5 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (1.6.0)
# Requirement already satisfied: numpy>=1.23.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (1.26.4)
# Requirement already satisfied: pandas>=1.0.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.9.2)
# Requirement already satisfied: python-dotenv<2.0,>=0.21 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (1.0.1)
# Requirement already satisfied: rich<14.0,>=13.6 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (13.9.3)
# Requirement already satisfied: sqlalchemy<3.0,>=2.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.0.36)
# Requirement already satisfied: typing_extensions<5.0,>=4.9 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-core<2.0.0,>=1.0.0->trulens_eval) (4.12.2)
# Collecting ipywidgets<9.0.0,>=8.1.2 (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting jupyter<2,>=1 (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting plotly<6.0.0,>=5.22.0 (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting psutil<6.0,>=5.9 (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading psutil-5.9.8-cp38-abi3-macosx_11_0_arm64.whl.metadata (21 kB)
# Collecting streamlit<2.0,>=1.35 (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: traitlets<6.0.0,>=5.0.5 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.14.3)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (3.9.1)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.3.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (1.5.2)
# Requirement already satisfied: scipy>=1.7.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (1.14.1)
# Collecting Mako (from alembic<2.0.0,>=1.8.1->trulens-core<2.0.0,>=1.0.0->trulens_eval)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (8.28.0)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting notebook (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached notebook-7.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (6.29.5)
# Collecting jupyterlab (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading jupyterlab-4.3.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from munch<3.0,>=2.5->trulens-core<2.0.0,>=1.0.0->trulens_eval) (1.16.0)
# Requirement already satisfied: click in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from pandas>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from pandas>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from pandas>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from plotly<6.0.0,>=5.22.0->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (8.4.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from plotly<6.0.0,>=5.22.0->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->trulens-core<2.0.0,>=1.0.0->trulens_eval) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from rich<14.0,>=13.6->trulens-core<2.0.0,>=1.0.0->trulens_eval) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from rich<14.0,>=13.6->trulens-core<2.0.0,>=1.0.0->trulens_eval) (2.18.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=1.3.0->trulens-feedback<2.0.0,>=1.0.0->trulens_eval) (3.5.0)
# Collecting altair<6,>=4.0 (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.5.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.28.3)
# Requirement already satisfied: pyarrow>=7.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.32.3)
# Collecting toml<2,>=0.10.1 (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (6.4.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.1.4)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading narwhals-1.13.5-py3-none-any.whl.metadata (7.4 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.0.48)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.9.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=13.6->trulens-core<2.0.0,>=1.0.0->trulens_eval) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2024.8.30)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.8.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (5.7.2)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (26.2.0)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.27.2)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (75.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from Mako->alembic<2.0.0,>=1.8.1->trulens-core<2.0.0,>=1.0.0->trulens_eval) (3.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.12.3)
# Collecting bleach!=5.0.0 (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting jupyterlab (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading jupyterlab-4.2.6-py3-none-any.whl.metadata (16 kB)
# Collecting webencodings (from bleach!=5.0.0->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.0.6)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (24.2.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading rpds_py-0.21.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (4.3.6)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (7.7.0)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached prometheus_client-0.21.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (1.8.0)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading json5-0.9.28-py3-none-any.whl.metadata (32 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9.0.0,>=8.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (0.2.3)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (6.0.2)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/kmy_env/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens_eval)
#   Using cached types_python_dateutil-2.9.0.20241003-py3-none-any.whl.metadata (1.9 kB)
# Downloading trulens_eval-1.2.7-py3-none-any.whl (37 kB)
# Downloading trulens_core-1.2.7-py3-none-any.whl (232 kB)
# Downloading trulens_dashboard-1.2.7-py3-none-any.whl (602 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 22.3 MB/s eta 0:00:00
# Downloading trulens_feedback-1.2.7-py3-none-any.whl (46 kB)
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Using cached plotly-5.24.1-py3-none-any.whl (19.1 MB)
# Downloading psutil-5.9.8-cp38-abi3-macosx_11_0_arm64.whl (249 kB)
# Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 17.1 MB/s eta 0:00:00a 0:00:01
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 20.3 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 29.3 MB/s eta 0:00:00a 0:00:01
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached notebook-7.2.2-py3-none-any.whl (5.0 MB)
# Downloading jupyterlab-4.2.6-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 14.6 MB/s eta 0:00:00a 0:00:01
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server-2.14.2-py3-none-any.whl (383 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# Downloading narwhals-1.13.5-py3-none-any.whl (208 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached babel-2.16.0-py3-none-any.whl (9.6 MB)
# Using cached fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Downloading json5-0.9.28-py3-none-any.whl (30 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached prometheus_client-0.21.0-py3-none-any.whl (54 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.21.0-cp312-cp312-macosx_11_0_arm64.whl (321 kB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl (178 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached types_python_dateutil-2.9.0.20241003-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, fastjsonschema, widgetsnbextension, webcolors, uri-template, types-python-dateutil, toml, tinycss2, terminado, smmap, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, python-json-logger, pycparser, psutil, prometheus-client, plotly, pandocfilters, narwhals, munch, mistune, Mako, jupyterlab-widgets, jupyterlab-pygments, json5, fqdn, defusedxml, blinker, bleach, babel, async-lru, referencing, pydeck, jupyter-server-terminals, gitdb, cffi, arrow, alembic, trulens-core, jsonschema-specifications, isoduration, gitpython, argon2-cffi-bindings, trulens-feedback, jsonschema, ipywidgets, argon2-cffi, nbformat, jupyter-console, altair, streamlit, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, trulens-dashboard, trulens_eval
#   Attempting uninstall: psutil
#     Found existing installation: psutil 6.0.0
#     Uninstalling psutil-6.0.0:
#       Successfully uninstalled psutil-6.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# colpali-engine 0.3.3 requires transformers<4.47.0,>=4.46.0, but you have transformers 4.44.2 which is incompatible.
# Successfully installed Mako-1.3.6 alembic-1.14.0 altair-5.4.1 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 babel-2.16.0 bleach-6.2.0 blinker-1.9.0 cffi-1.17.1 defusedxml-0.7.1 fastjsonschema-2.20.0 fqdn-1.5.1 gitdb-4.0.11 gitpython-3.1.43 ipywidgets-8.1.5 isoduration-20.11.0 json5-0.9.28 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.6 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 mistune-3.0.2 munch-2.5.0 narwhals-1.13.5 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 notebook-7.2.2 notebook-shim-0.2.4 pandocfilters-1.5.1 plotly-5.24.1 prometheus-client-0.21.0 psutil-5.9.8 pycparser-2.22 pydeck-0.9.1 python-json-logger-2.0.7 referencing-0.35.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.21.0 send2trash-1.8.3 smmap-5.0.1 streamlit-1.40.1 terminado-0.18.1 tinycss2-1.4.0 toml-0.10.2 trulens-core-1.2.7 trulens-dashboard-1.2.7 trulens-feedback-1.2.7 trulens_eval-1.2.7 types-python-dateutil-2.9.0.20241003 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 widgetsnbextension-4.0.13
